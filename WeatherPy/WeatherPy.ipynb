# %%
import matplotlib.pyplot as plt
import requests
from scipy import stats
from scipy.stats import linregress
import pandas as pd
from api_keys import weather_api_key
import json
import numpy as np
from citipy import citipy
import time

#output file
output_data_csv = "Output/weather_data.csv"

# %%
#make lists
cities = []
coordinates = []

#select range 
latitude_range= (-90, 90)
longitude_range = (-180, 180)

#find random values for the coordinates within the range
latitudes= np.random.uniform(low=-90, high = 90, size= 1200)
longitudes= np.random.uniform(low=-180, high = 180, size= 1200)
coordinates= list(zip(latitudes, longitudes))

for coordinate in coordinates:
    city= citipy.nearest_city(coordinate [0], coordinate [1]).city_name
    if city not in cities:
        cities.append(city)

list_data= list(zip(cities,coordinates))
list_data_2 = pd.DataFrame(list_data, columns=["City", "Coordinates"])
list_data_2.head()
# Out:
#            City                                Coordinates
# 0       ushuaia    (-87.1749054784666, -83.63802221882779)
# 1  puerto ayora   (-5.375752407884818, -97.60769540631601)
# 2   yellowknife   (79.66624606767985, -103.66600617684276)
# 3         kroya   (-9.262302760257427, 108.52448185214428)
# 4  punta arenas  (-54.550500326165654, -72.70930716853776)

# %%
# set lists for the dataframe
city_list = []
lat= []
lng=[]
max_temp=[]
humidity=[]
cloudiness=[]
wind_speed=[]
country=[]
date=[]

# %%
# loops for creating dataframe columns
for index, row in list_data_2.iterrows():
    time.sleep(1)
    city=row["City"]
    url= f"http://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&appid={weather_api_key}"
    response = requests.get(url).json()
    print(json.dumps(response,indent=4))
    

    if response['cod']==200:
        lat.append(response['coord']['lat'])
        lng.append(response ['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_list.append(city)

    else:
        print("City not found. Skipping...")
# Out:
# {
#     "coord": {
#         "lon": -68.3,
#         "lat": -54.8
#     },
#     "weather": [
#         {
#             "id": 521,
#             "main": "Rain",
#             "description": "shower rain",
#             "icon": "09n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 35.6,
#         "feels_like": 22.59,
#         "temp_min": 35.6,
#         "temp_max": 35.6,
#         "pressure": 983,
#         "humidity": 93
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 17.22,
#         "deg": 230
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1600134035,
#     "sys": {
#         "type": 1,
#         "id": 8303,
#         "country": "AR",
#         "sunrise": 1600080054,
#         "sunset": 1600121791
#     },
#     "timezone": -10800,
#     "id": 3833367,
#     "name": "Ushuaia",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -90.35,
#         "lat": -0.74
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 66.99,
#         "feels_like": 68.88,
#         "temp_min": 66.99,
#         "temp_max": 66.99,
#         "pressure": 1014,
#         "humidity": 89
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.01,
#         "deg": 155,
#         "gust": 10
#     },
#     "clouds": {
#         "all": 76
#     },
#     "dt": 1600134037,
#     "sys": {
#         "type": 3,
#         "id": 2005652,
#         "country": "EC",
#         "sunrise": 1600084424,
#         "sunset": 1600128003
#     },
#     "timezone": -21600,
#     "id": 3652764,
#     "name": "Puerto Ayora",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -114.35,
#         "lat": 62.46
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 46.15,
#         "feels_like": 38.44,
#         "temp_min": 46,
#         "temp_max": 46.4,
#         "pressure": 1015,
#         "humidity": 64
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.05,
#         "deg": 250
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1600134038,
#     "sys": {
#         "type": 1,
#         "id": 1007,
#         "country": "CA",
#         "sunrise": 1600088500,
#         "sunset": 1600135444
#     },
#     "timezone": -21600,
#     "id": 6185377,
#     "name": "Yellowknife",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 109.25,
#         "lat": -7.63
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 80.69,
#         "feels_like": 84.13,
#         "temp_min": 80.69,
#         "temp_max": 80.69,
#         "pressure": 1014,
#         "humidity": 67,
#         "sea_level": 1014,
#         "grnd_level": 1012
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.31,
#         "deg": 134
#     },
#     "clouds": {
#         "all": 93
#     },
#     "dt": 1600134039,
#     "sys": {
#         "country": "ID",
#         "sunrise": 1600122994,
#         "sunset": 1600166405
#     },
#     "timezone": 25200,
#     "id": 1639337,
#     "name": "Kroya",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -70.92,
#         "lat": -53.15
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 36.18,
#         "feels_like": 18.43,
#         "temp_min": 35.01,
#         "temp_max": 37.4,
#         "pressure": 991,
#         "humidity": 86
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 25.28,
#         "deg": 300
#     },
#     "clouds": {
#         "all": 55
#     },
#     "dt": 1600133776,
#     "sys": {
#         "type": 1,
#         "id": 8487,
#         "country": "CL",
#         "sunrise": 1600080632,
#         "sunset": 1600122471
#     },
#     "timezone": -10800,
#     "id": 3874787,
#     "name": "Punta Arenas",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 150.8,
#         "lat": -2.57
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 84.42,
#         "feels_like": 87.57,
#         "temp_min": 84.42,
#         "temp_max": 84.42,
#         "pressure": 1008,
#         "humidity": 75,
#         "sea_level": 1008,
#         "grnd_level": 1007
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 13.42,
#         "deg": 101
#     },
#     "rain": {
#         "1h": 0.34
#     },
#     "clouds": {
#         "all": 85
#     },
#     "dt": 1600134041,
#     "sys": {
#         "country": "PG",
#         "sunrise": 1600112963,
#         "sunset": 1600156497
#     },
#     "timezone": 36000,
#     "id": 2094342,
#     "name": "Kavieng",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found. Skipping...
# {
#     "coord": {
#         "lon": 77.59,
#         "lat": 60.73
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 51.8,
#         "feels_like": 45.48,
#         "temp_min": 51.8,
#         "temp_max": 51.8,
#         "pressure": 1011,
#         "humidity": 76
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.95,
#         "deg": 150
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134043,
#     "sys": {
#         "type": 1,
#         "id": 8986,
#         "country": "RU",
#         "sunrise": 1600129026,
#         "sunset": 1600175566
#     },
#     "timezone": 25200,
#     "id": 1490796,
#     "name": "Strezhevoy",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 36.2,
#         "lat": 16.15
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 82.44,
#         "feels_like": 82.54,
#         "temp_min": 82.44,
#         "temp_max": 82.44,
#         "pressure": 1008,
#         "humidity": 62,
#         "sea_level": 1008,
#         "grnd_level": 961
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 11.7,
#         "deg": 183
#     },
#     "clouds": {
#         "all": 67
#     },
#     "dt": 1600134044,
#     "sys": {
#         "country": "SD",
#         "sunrise": 1600140218,
#         "sunset": 1600184236
#     },
#     "timezone": 7200,
#     "id": 364027,
#     "name": "Wagar",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -37.64,
#         "lat": 65.61
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 22.35,
#         "feels_like": 15.48,
#         "temp_min": 22.35,
#         "temp_max": 22.35,
#         "pressure": 1021,
#         "humidity": 96,
#         "sea_level": 1021,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.58,
#         "deg": 355
#     },
#     "clouds": {
#         "all": 23
#     },
#     "dt": 1600134045,
#     "sys": {
#         "country": "GL",
#         "sunrise": 1600069780,
#         "sunset": 1600117352
#     },
#     "timezone": -7200,
#     "id": 3424607,
#     "name": "Tasiilaq",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 161.3,
#         "lat": 68.75
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 51.6,
#         "feels_like": 43.36,
#         "temp_min": 51.6,
#         "temp_max": 51.6,
#         "pressure": 1011,
#         "humidity": 55,
#         "sea_level": 1011,
#         "grnd_level": 1011
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 9.4,
#         "deg": 51
#     },
#     "clouds": {
#         "all": 32
#     },
#     "dt": 1600134047,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1600108179,
#         "sunset": 1600156242
#     },
#     "timezone": 39600,
#     "id": 2126199,
#     "name": "Cherskiy",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -99.89,
#         "lat": 16.86
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 84.2,
#         "feels_like": 89.38,
#         "temp_min": 84.2,
#         "temp_max": 84.2,
#         "pressure": 1011,
#         "humidity": 74
#     },
#     "visibility": 9656,
#     "wind": {
#         "speed": 9.17,
#         "deg": 260
#     },
#     "clouds": {
#         "all": 90
#     },
#     "dt": 1600134048,
#     "sys": {
#         "type": 1,
#         "id": 7103,
#         "country": "MX",
#         "sunrise": 1600086466,
#         "sunset": 1600130539
#     },
#     "timezone": -18000,
#     "id": 3533462,
#     "name": "Acapulco de Ju\u00e1rez",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 62.58,
#         "lat": 52.68
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 54.86,
#         "feels_like": 46.2,
#         "temp_min": 54.86,
#         "temp_max": 54.86,
#         "pressure": 999,
#         "humidity": 57,
#         "sea_level": 999,
#         "grnd_level": 976
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 11.41,
#         "deg": 271
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134049,
#     "sys": {
#         "country": "KZ",
#         "sunrise": 1600133047,
#         "sunset": 1600178748
#     },
#     "timezone": 21600,
#     "id": 1518139,
#     "name": "Tobol",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -73.82,
#         "lat": -41.87
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 43.7,
#         "feels_like": 39.25,
#         "temp_min": 39.99,
#         "temp_max": 48.99,
#         "pressure": 1027,
#         "humidity": 97
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.01,
#         "deg": 293,
#         "gust": 8.99
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134050,
#     "sys": {
#         "type": 3,
#         "id": 2033614,
#         "country": "CL",
#         "sunrise": 1600081059,
#         "sunset": 1600123435
#     },
#     "timezone": -10800,
#     "id": 3899695,
#     "name": "Ancud",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -54.33,
#         "lat": -34.48
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 40.15,
#         "feels_like": 35.74,
#         "temp_min": 40.15,
#         "temp_max": 40.15,
#         "pressure": 1028,
#         "humidity": 85,
#         "sea_level": 1028,
#         "grnd_level": 1025
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.59,
#         "deg": 269
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1600134051,
#     "sys": {
#         "country": "UY",
#         "sunrise": 1600076253,
#         "sunset": 1600118888
#     },
#     "timezone": -10800,
#     "id": 3440777,
#     "name": "Rocha",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -152.41,
#         "lat": 57.79
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 56.44,
#         "feels_like": 48.81,
#         "temp_min": 56.44,
#         "temp_max": 56.44,
#         "pressure": 1019,
#         "humidity": 65,
#         "sea_level": 1019,
#         "grnd_level": 1012
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 11.41,
#         "deg": 186
#     },
#     "clouds": {
#         "all": 42
#     },
#     "dt": 1600134052,
#     "sys": {
#         "country": "US",
#         "sunrise": 1600097954,
#         "sunset": 1600144254
#     },
#     "timezone": -28800,
#     "id": 5866583,
#     "name": "Saint Paul Harbor",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -69.36,
#         "lat": 77.48
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 26.89,
#         "feels_like": 18.64,
#         "temp_min": 26.89,
#         "temp_max": 26.89,
#         "pressure": 1017,
#         "humidity": 91,
#         "sea_level": 1017,
#         "grnd_level": 1017
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.62,
#         "deg": 72
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1600133782,
#     "sys": {
#         "country": "GL",
#         "sunrise": 1600075160,
#         "sunset": 1600127195
#     },
#     "timezone": -10800,
#     "id": 3831208,
#     "name": "Qaanaaq",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -114.06,
#         "lat": 27.98
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 79.88,
#         "feels_like": 73.99,
#         "temp_min": 79.88,
#         "temp_max": 79.88,
#         "pressure": 1012,
#         "humidity": 49,
#         "sea_level": 1012,
#         "grnd_level": 1012
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 15.59,
#         "deg": 329
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1600134054,
#     "sys": {
#         "country": "MX",
#         "sunrise": 1600089679,
#         "sunset": 1600134126
#     },
#     "timezone": -21600,
#     "id": 4021858,
#     "name": "Guerrero Negro",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 32.88,
#         "lat": -13.8
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 62.6,
#         "feels_like": 60.82,
#         "temp_min": 62.6,
#         "temp_max": 62.6,
#         "pressure": 1013,
#         "humidity": 67,
#         "sea_level": 1013,
#         "grnd_level": 882
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.03,
#         "deg": 81
#     },
#     "clouds": {
#         "all": 16
#     },
#     "dt": 1600134056,
#     "sys": {
#         "country": "MW",
#         "sunrise": 1600141389,
#         "sunset": 1600184659
#     },
#     "timezone": 7200,
#     "id": 926747,
#     "name": "Mchinji",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 141.43,
#         "lat": -31.95
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 64.4,
#         "feels_like": 55.15,
#         "temp_min": 64.4,
#         "temp_max": 64.4,
#         "pressure": 1029,
#         "humidity": 42
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 12.75,
#         "deg": 100
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1600134057,
#     "sys": {
#         "type": 1,
#         "id": 9491,
#         "country": "AU",
#         "sunrise": 1600115593,
#         "sunset": 1600158364
#     },
#     "timezone": 34200,
#     "id": 2173911,
#     "name": "Broken Hill",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -79.24,
#         "lat": 42.1
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 49.33,
#         "feels_like": 45.19,
#         "temp_min": 46.99,
#         "temp_max": 51.01,
#         "pressure": 1028,
#         "humidity": 71
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.53,
#         "deg": 41
#     },
#     "clouds": {
#         "all": 1
#     },
#     "dt": 1600134061,
#     "sys": {
#         "type": 1,
#         "id": 4588,
#         "country": "US",
#         "sunrise": 1600080994,
#         "sunset": 1600126102
#     },
#     "timezone": -14400,
#     "id": 5122534,
#     "name": "Jamestown",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 15.64,
#         "lat": 78.22
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 33.8,
#         "feels_like": 26.37,
#         "temp_min": 33.8,
#         "temp_max": 33.8,
#         "pressure": 1014,
#         "humidity": 94
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.93,
#         "deg": 50
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1600134062,
#     "sys": {
#         "type": 1,
#         "id": 1663,
#         "country": "SJ",
#         "sunrise": 1600141207,
#         "sunset": 1600193114
#     },
#     "timezone": 7200,
#     "id": 2729907,
#     "name": "Longyearbyen",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found. Skipping...
# {
#     "coord": {
#         "lon": -175.2,
#         "lat": -21.2
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 77,
#         "feels_like": 77.7,
#         "temp_min": 77,
#         "temp_max": 77,
#         "pressure": 1018,
#         "humidity": 73
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 10.29,
#         "deg": 90
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1600134064,
#     "sys": {
#         "type": 1,
#         "id": 7285,
#         "country": "TO",
#         "sunrise": 1600191384,
#         "sunset": 1600234516
#     },
#     "timezone": 46800,
#     "id": 4032243,
#     "name": "Vaini",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -73.58,
#         "lat": 40.66
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 65.3,
#         "feels_like": 54.32,
#         "temp_min": 64,
#         "temp_max": 66.2,
#         "pressure": 1022,
#         "humidity": 37
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 14.99,
#         "deg": 10,
#         "gust": 21.92
#     },
#     "clouds": {
#         "all": 1
#     },
#     "dt": 1600133799,
#     "sys": {
#         "type": 1,
#         "id": 4135,
#         "country": "US",
#         "sunrise": 1600079674,
#         "sunset": 1600124705
#     },
#     "timezone": -14400,
#     "id": 5117949,
#     "name": "Freeport",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 69.9,
#         "lat": 60.05
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 49.96,
#         "feels_like": 48.07,
#         "temp_min": 49.96,
#         "temp_max": 49.96,
#         "pressure": 1005,
#         "humidity": 96,
#         "sea_level": 1005,
#         "grnd_level": 1001
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.95,
#         "deg": 140
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134066,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1600130918,
#         "sunset": 1600177365
#     },
#     "timezone": 18000,
#     "id": 1506268,
#     "name": "Gornopravdinsk",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 27.85,
#         "lat": 71.04
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 45.86,
#         "feels_like": 37.29,
#         "temp_min": 45.86,
#         "temp_max": 45.86,
#         "pressure": 1012,
#         "humidity": 84,
#         "sea_level": 1012,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 11.72,
#         "deg": 45
#     },
#     "rain": {
#         "1h": 0.154
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1600133844,
#     "sys": {
#         "country": "NO",
#         "sunrise": 1600139985,
#         "sunset": 1600188476
#     },
#     "timezone": 7200,
#     "id": 778707,
#     "name": "Mehamn",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -28.7,
#         "lat": 38.52
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 66.67,
#         "feels_like": 59.92,
#         "temp_min": 66.67,
#         "temp_max": 66.67,
#         "pressure": 1023,
#         "humidity": 64,
#         "sea_level": 1023,
#         "grnd_level": 1020
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 14.23,
#         "deg": 349
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134068,
#     "sys": {
#         "country": "PT",
#         "sunrise": 1600155404,
#         "sunset": 1600200194
#     },
#     "timezone": 0,
#     "id": 3372707,
#     "name": "Ribeira Grande",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 140.83,
#         "lat": 35.73
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 78.48,
#         "feels_like": 78.04,
#         "temp_min": 75,
#         "temp_max": 82,
#         "pressure": 1014,
#         "humidity": 74
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 13.87,
#         "deg": 40
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1600134069,
#     "sys": {
#         "type": 1,
#         "id": 7955,
#         "country": "JP",
#         "sunrise": 1600114757,
#         "sunset": 1600159487
#     },
#     "timezone": 32400,
#     "id": 2112802,
#     "name": "Hasaki",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 141.97,
#         "lat": -38.27
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 57.42,
#         "feels_like": 53.69,
#         "temp_min": 57.42,
#         "temp_max": 57.42,
#         "pressure": 1029,
#         "humidity": 69,
#         "sea_level": 1029,
#         "grnd_level": 1027
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.53,
#         "deg": 234
#     },
#     "clouds": {
#         "all": 8
#     },
#     "dt": 1600134071,
#     "sys": {
#         "country": "AU",
#         "sunrise": 1600115564,
#         "sunset": 1600158134
#     },
#     "timezone": 36000,
#     "id": 2171099,
#     "name": "Codrington",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 29.64,
#         "lat": -1.5
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 59.81,
#         "feels_like": 59.47,
#         "temp_min": 59.81,
#         "temp_max": 59.81,
#         "pressure": 1013,
#         "humidity": 70,
#         "sea_level": 1013,
#         "grnd_level": 818
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.76,
#         "deg": 261
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1600134072,
#     "sys": {
#         "country": "RW",
#         "sunrise": 1600142020,
#         "sunset": 1600185583
#     },
#     "timezone": 7200,
#     "id": 201521,
#     "name": "Ruhengeri",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -97.86,
#         "lat": 55.74
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 39.2,
#         "feels_like": 33.87,
#         "temp_min": 39.2,
#         "temp_max": 39.2,
#         "pressure": 1021,
#         "humidity": 93
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.65,
#         "deg": 74
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1600134018,
#     "sys": {
#         "type": 1,
#         "id": 935,
#         "country": "CA",
#         "sunrise": 1600084953,
#         "sunset": 1600131077
#     },
#     "timezone": -18000,
#     "id": 6165406,
#     "name": "Thompson",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 12.78,
#         "lat": 26.59
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 75.15,
#         "feels_like": 71.08,
#         "temp_min": 75.15,
#         "temp_max": 75.15,
#         "pressure": 1013,
#         "humidity": 35,
#         "sea_level": 1013,
#         "grnd_level": 960
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.39,
#         "deg": 336
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1600134074,
#     "sys": {
#         "country": "LY",
#         "sunrise": 1600145679,
#         "sunset": 1600190014
#     },
#     "timezone": 7200,
#     "id": 2219235,
#     "name": "Ubari",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -72.07,
#         "lat": -45.58
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 46.4,
#         "feels_like": 39.43,
#         "temp_min": 46.4,
#         "temp_max": 46.4,
#         "pressure": 1010,
#         "humidity": 65
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.93,
#         "deg": 0
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1600134075,
#     "sys": {
#         "type": 1,
#         "id": 8491,
#         "country": "CL",
#         "sunrise": 1600080717,
#         "sunset": 1600122938
#     },
#     "timezone": -10800,
#     "id": 3894426,
#     "name": "Coyhaique",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 168.86,
#         "lat": -46.19
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 46.99,
#         "feels_like": 39.61,
#         "temp_min": 46.99,
#         "temp_max": 46.99,
#         "pressure": 997,
#         "humidity": 75
#     },
#     "visibility": 9291,
#     "wind": {
#         "speed": 8.99,
#         "deg": 301,
#         "gust": 18.01
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134076,
#     "sys": {
#         "type": 3,
#         "id": 2008959,
#         "country": "NZ",
#         "sunrise": 1600109268,
#         "sunset": 1600151526
#     },
#     "timezone": 43200,
#     "id": 6201424,
#     "name": "Mataura",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 117.5,
#         "lat": 0.13
#     },
#     "weather": [
#         {
#             "id": 501,
#             "main": "Rain",
#             "description": "moderate rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 82.63,
#         "feels_like": 85.48,
#         "temp_min": 82.63,
#         "temp_max": 82.63,
#         "pressure": 1011,
#         "humidity": 72,
#         "sea_level": 1011,
#         "grnd_level": 1011
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 10.98,
#         "deg": 233
#     },
#     "rain": {
#         "1h": 1.332
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134078,
#     "sys": {
#         "country": "ID",
#         "sunrise": 1600120919,
#         "sunset": 1600164521
#     },
#     "timezone": 28800,
#     "id": 1648186,
#     "name": "Bontang",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found. Skipping...
# {
#     "coord": {
#         "lon": -76.9,
#         "lat": 34.88
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 73.87,
#         "feels_like": 74.75,
#         "temp_min": 73,
#         "temp_max": 75,
#         "pressure": 1020,
#         "humidity": 94
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 13.87,
#         "deg": 20
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1600133995,
#     "sys": {
#         "type": 1,
#         "id": 5098,
#         "country": "US",
#         "sunrise": 1600080614,
#         "sunset": 1600125358
#     },
#     "timezone": -14400,
#     "id": 4470244,
#     "name": "Havelock",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 80.55,
#         "lat": 73.51
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 43.02,
#         "feels_like": 33.19,
#         "temp_min": 43.02,
#         "temp_max": 43.02,
#         "pressure": 1008,
#         "humidity": 91,
#         "sea_level": 1008,
#         "grnd_level": 1002
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 13.69,
#         "deg": 155
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134081,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1600126872,
#         "sunset": 1600176299
#     },
#     "timezone": 25200,
#     "id": 1507390,
#     "name": "Dikson",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 20.04,
#         "lat": -34.53
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 39.2,
#         "feels_like": 35.85,
#         "temp_min": 39.2,
#         "temp_max": 39.2,
#         "pressure": 1021,
#         "humidity": 93
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.12,
#         "deg": 70
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134082,
#     "sys": {
#         "type": 1,
#         "id": 1966,
#         "country": "ZA",
#         "sunrise": 1600144737,
#         "sunset": 1600187472
#     },
#     "timezone": 7200,
#     "id": 1015776,
#     "name": "Bredasdorp",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -72.33,
#         "lat": 42.16
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 56.84,
#         "feels_like": 46.6,
#         "temp_min": 53.01,
#         "temp_max": 60.01,
#         "pressure": 1022,
#         "humidity": 51
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 13.87,
#         "deg": 20
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1600134083,
#     "sys": {
#         "type": 1,
#         "id": 3598,
#         "country": "US",
#         "sunrise": 1600079333,
#         "sunset": 1600124447
#     },
#     "timezone": -14400,
#     "id": 4946620,
#     "name": "Palmer",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -65.1,
#         "lat": -43.3
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 61.77,
#         "feels_like": 51.64,
#         "temp_min": 61.77,
#         "temp_max": 61.77,
#         "pressure": 1009,
#         "humidity": 43,
#         "sea_level": 1009,
#         "grnd_level": 1008
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 13.73,
#         "deg": 278
#     },
#     "clouds": {
#         "all": 85
#     },
#     "dt": 1600134085,
#     "sys": {
#         "country": "AR",
#         "sunrise": 1600078998,
#         "sunset": 1600121312
#     },
#     "timezone": -10800,
#     "id": 3839307,
#     "name": "Rawson",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -97.07,
#         "lat": 15.85
#     },
#     "weather": [
#         {
#             "id": 300,
#             "main": "Drizzle",
#             "description": "light intensity drizzle",
#             "icon": "09n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 77,
#         "feels_like": 80.53,
#         "temp_min": 77,
#         "temp_max": 77,
#         "pressure": 1013,
#         "humidity": 78
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.93,
#         "deg": 60
#     },
#     "clouds": {
#         "all": 90
#     },
#     "dt": 1600134086,
#     "sys": {
#         "type": 1,
#         "id": 7157,
#         "country": "MX",
#         "sunrise": 1600085805,
#         "sunset": 1600129847
#     },
#     "timezone": -18000,
#     "id": 3520994,
#     "name": "Puerto Escondido",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found. Skipping...
# {
#     "coord": {
#         "lon": 73.08,
#         "lat": -0.6
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 81.21,
#         "feels_like": 86.04,
#         "temp_min": 81.21,
#         "temp_max": 81.21,
#         "pressure": 1011,
#         "humidity": 66,
#         "sea_level": 1011,
#         "grnd_level": 1011
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.89,
#         "deg": 216
#     },
#     "clouds": {
#         "all": 95
#     },
#     "dt": 1600134088,
#     "sys": {
#         "country": "MV",
#         "sunrise": 1600131586,
#         "sunset": 1600175170
#     },
#     "timezone": 18000,
#     "id": 1282256,
#     "name": "Hithadhoo",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 147.92,
#         "lat": 70.63
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 45.52,
#         "feels_like": 37.8,
#         "temp_min": 45.52,
#         "temp_max": 45.52,
#         "pressure": 1016,
#         "humidity": 81,
#         "sea_level": 1016,
#         "grnd_level": 1010
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 9.78,
#         "deg": 45
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134089,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1600111146,
#         "sunset": 1600159696
#     },
#     "timezone": 39600,
#     "id": 2126123,
#     "name": "Chokurdakh",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -159.32,
#         "lat": 22.08
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 83.7,
#         "feels_like": 83.61,
#         "temp_min": 81,
#         "temp_max": 86,
#         "pressure": 1016,
#         "humidity": 58
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 11.41,
#         "deg": 60
#     },
#     "clouds": {
#         "all": 1
#     },
#     "dt": 1600133801,
#     "sys": {
#         "type": 1,
#         "id": 7873,
#         "country": "US",
#         "sunrise": 1600100648,
#         "sunset": 1600144876
#     },
#     "timezone": -36000,
#     "id": 5848280,
#     "name": "Kapaa",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -97.7,
#         "lat": 26.19
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 78.93,
#         "feels_like": 85.41,
#         "temp_min": 78.8,
#         "temp_max": 79,
#         "pressure": 1014,
#         "humidity": 88
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.93,
#         "deg": 350
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1600134091,
#     "sys": {
#         "type": 1,
#         "id": 4420,
#         "country": "US",
#         "sunrise": 1600085784,
#         "sunset": 1600130170
#     },
#     "timezone": -18000,
#     "id": 4696233,
#     "name": "Harlingen",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -34.81,
#         "lat": -7.47
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 73.4,
#         "feels_like": 79.95,
#         "temp_min": 73.4,
#         "temp_max": 73.4,
#         "pressure": 1018,
#         "humidity": 94
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.36,
#         "deg": 170
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1600134093,
#     "sys": {
#         "type": 1,
#         "id": 8391,
#         "country": "BR",
#         "sunrise": 1600071187,
#         "sunset": 1600114588
#     },
#     "timezone": -10800,
#     "id": 3391889,
#     "name": "Pitimbu",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 26.89,
#         "lat": -33.59
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 54.52,
#         "feels_like": 44.76,
#         "temp_min": 54.52,
#         "temp_max": 54.52,
#         "pressure": 1022,
#         "humidity": 71,
#         "sea_level": 1022,
#         "grnd_level": 1020
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 15.37,
#         "deg": 267
#     },
#     "clouds": {
#         "all": 15
#     },
#     "dt": 1600134094,
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1600143081,
#         "sunset": 1600185841
#     },
#     "timezone": 7200,
#     "id": 964432,
#     "name": "Port Alfred",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 19.23,
#         "lat": -34.42
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 39.99,
#         "feels_like": 33.93,
#         "temp_min": 39.99,
#         "temp_max": 39.99,
#         "pressure": 1023,
#         "humidity": 95
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.38,
#         "deg": 42
#     },
#     "clouds": {
#         "all": 61
#     },
#     "dt": 1600134095,
#     "sys": {
#         "type": 3,
#         "id": 2006131,
#         "country": "ZA",
#         "sunrise": 1600144930,
#         "sunset": 1600187668
#     },
#     "timezone": 7200,
#     "id": 3366880,
#     "name": "Hermanus",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 135.87,
#         "lat": -34.73
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 58.42,
#         "feels_like": 52.41,
#         "temp_min": 58.42,
#         "temp_max": 58.42,
#         "pressure": 1029,
#         "humidity": 69,
#         "sea_level": 1029,
#         "grnd_level": 1025
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 10.02,
#         "deg": 64
#     },
#     "clouds": {
#         "all": 17
#     },
#     "dt": 1600134096,
#     "sys": {
#         "country": "AU",
#         "sunrise": 1600116969,
#         "sunset": 1600159656
#     },
#     "timezone": 34200,
#     "id": 2063036,
#     "name": "Port Lincoln",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -133.04,
#         "lat": 69.45
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 32,
#         "feels_like": 22.64,
#         "temp_min": 32,
#         "temp_max": 32,
#         "pressure": 1026,
#         "humidity": 83
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 9.17,
#         "deg": 70
#     },
#     "clouds": {
#         "all": 90
#     },
#     "dt": 1600134097,
#     "sys": {
#         "type": 1,
#         "id": 942,
#         "country": "CA",
#         "sunrise": 1600092290,
#         "sunset": 1600140623
#     },
#     "timezone": -21600,
#     "id": 6170031,
#     "name": "Tuktoyaktuk",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 45.57,
#         "lat": 39.41
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 69.8,
#         "feels_like": 64.65,
#         "temp_min": 69.8,
#         "temp_max": 69.8,
#         "pressure": 1017,
#         "humidity": 49
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 9.17,
#         "deg": 80
#     },
#     "clouds": {
#         "all": 20
#     },
#     "dt": 1600134098,
#     "sys": {
#         "type": 1,
#         "id": 8839,
#         "country": "AZ",
#         "sunrise": 1600137548,
#         "sunset": 1600182410
#     },
#     "timezone": 14400,
#     "id": 147278,
#     "name": "\u015eahbuz",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 25.02,
#         "lat": 45.75
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 55.53,
#         "feels_like": 52.29,
#         "temp_min": 54,
#         "temp_max": 57,
#         "pressure": 1025,
#         "humidity": 84
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 6.29,
#         "deg": 137
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1600134100,
#     "sys": {
#         "type": 3,
#         "id": 38347,
#         "country": "RO",
#         "sunrise": 1600142313,
#         "sunset": 1600187506
#     },
#     "timezone": 10800,
#     "id": 676169,
#     "name": "H\u00e2r\u015feni",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 103.72,
#         "lat": 27.32
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 59,
#         "feels_like": 59.14,
#         "temp_min": 59,
#         "temp_max": 59,
#         "pressure": 1011,
#         "humidity": 93,
#         "sea_level": 1011,
#         "grnd_level": 807
#     },
#     "visibility": 308,
#     "wind": {
#         "speed": 3.65,
#         "deg": 48
#     },
#     "rain": {
#         "1h": 0.2004
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134102,
#     "sys": {
#         "country": "CN",
#         "sunrise": 1600123834,
#         "sunset": 1600168219
#     },
#     "timezone": 28800,
#     "id": 1784841,
#     "name": "Zhaotong",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -156.79,
#         "lat": 71.29
#     },
#     "weather": [
#         {
#             "id": 701,
#             "main": "Mist",
#             "description": "mist",
#             "icon": "50d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 39.2,
#         "feels_like": 28.67,
#         "temp_min": 39.2,
#         "temp_max": 39.2,
#         "pressure": 1021,
#         "humidity": 93
#     },
#     "visibility": 1207,
#     "wind": {
#         "speed": 13.87,
#         "deg": 80
#     },
#     "clouds": {
#         "all": 90
#     },
#     "dt": 1600134001,
#     "sys": {
#         "type": 1,
#         "id": 7649,
#         "country": "US",
#         "sunrise": 1600097736,
#         "sunset": 1600146574
#     },
#     "timezone": -28800,
#     "id": 5880054,
#     "name": "Barrow",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 164.02,
#         "lat": -20.23
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 74.14,
#         "feels_like": 72.16,
#         "temp_min": 74.14,
#         "temp_max": 74.14,
#         "pressure": 1018,
#         "humidity": 72,
#         "sea_level": 1018,
#         "grnd_level": 1018
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 12.55,
#         "deg": 99
#     },
#     "clouds": {
#         "all": 4
#     },
#     "dt": 1600134104,
#     "sys": {
#         "country": "NC",
#         "sunrise": 1600110014,
#         "sunset": 1600153103
#     },
#     "timezone": 39600,
#     "id": 2138555,
#     "name": "Poum",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 113.63,
#         "lat": -24.87
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 71.6,
#         "feels_like": 73.33,
#         "temp_min": 71.6,
#         "temp_max": 71.6,
#         "pressure": 1017,
#         "humidity": 94
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 10.29,
#         "deg": 200
#     },
#     "clouds": {
#         "all": 3
#     },
#     "dt": 1600134105,
#     "sys": {
#         "type": 1,
#         "id": 9505,
#         "country": "AU",
#         "sunrise": 1600122160,
#         "sunset": 1600165137
#     },
#     "timezone": 28800,
#     "id": 2074865,
#     "name": "Carnarvon",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found. Skipping...
# {
#     "coord": {
#         "lon": -70.2,
#         "lat": -22.09
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 60.51,
#         "feels_like": 58.12,
#         "temp_min": 60.51,
#         "temp_max": 60.51,
#         "pressure": 1018,
#         "humidity": 62,
#         "sea_level": 1018,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.22,
#         "deg": 195
#     },
#     "clouds": {
#         "all": 49
#     },
#     "dt": 1600134107,
#     "sys": {
#         "country": "CL",
#         "sunrise": 1600079872,
#         "sunset": 1600122886
#     },
#     "timezone": -10800,
#     "id": 3869716,
#     "name": "Tocopilla",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 60.31,
#         "lat": 65.98
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 44.55,
#         "feels_like": 37.99,
#         "temp_min": 44.55,
#         "temp_max": 44.55,
#         "pressure": 996,
#         "humidity": 86,
#         "sea_level": 996,
#         "grnd_level": 985
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.9,
#         "deg": 122
#     },
#     "clouds": {
#         "all": 91
#     },
#     "dt": 1600134108,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1600132772,
#         "sunset": 1600180112
#     },
#     "timezone": 10800,
#     "id": 1487332,
#     "name": "Verkhnyaya Inta",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 27.91,
#         "lat": -33.02
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 57.25,
#         "feels_like": 46.87,
#         "temp_min": 57.25,
#         "temp_max": 57.25,
#         "pressure": 1022,
#         "humidity": 60,
#         "sea_level": 1022,
#         "grnd_level": 1017
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 15.77,
#         "deg": 263
#     },
#     "clouds": {
#         "all": 1
#     },
#     "dt": 1600134110,
#     "sys": {
#         "country": "ZA",
# ...
#         "sunset": 1600121462
#     },
#     "timezone": -10800,
#     "id": 3836620,
#     "name": "Or\u00e1n",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 8.53,
#         "lat": 39.93
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 72,
#         "feels_like": 69.93,
#         "temp_min": 72,
#         "temp_max": 72,
#         "pressure": 1023,
#         "humidity": 43
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3,
#         "deg": 225,
#         "gust": 4
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1600134616,
#     "sys": {
#         "type": 3,
#         "id": 2016645,
#         "country": "IT",
#         "sunrise": 1600146430,
#         "sunset": 1600191302
#     },
#     "timezone": 7200,
#     "id": 2525478,
#     "name": "Cabras",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 96.13,
#         "lat": 4.14
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 81.86,
#         "feels_like": 88.3,
#         "temp_min": 81.86,
#         "temp_max": 81.86,
#         "pressure": 1012,
#         "humidity": 73,
#         "sea_level": 1012,
#         "grnd_level": 1012
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.27,
#         "deg": 64
#     },
#     "clouds": {
#         "all": 83
#     },
#     "dt": 1600134617,
#     "sys": {
#         "country": "ID",
#         "sunrise": 1600125996,
#         "sunset": 1600169699
#     },
#     "timezone": 25200,
#     "id": 1214488,
#     "name": "Meulaboh",
#     "cod": 200
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found. Skipping...
# {
#     "coord": {
#         "lon": -125.75,
#         "lat": 54.23
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 54.55,
#         "feels_like": 51.3,
#         "temp_min": 54.55,
#         "temp_max": 54.55,
#         "pressure": 1018,
#         "humidity": 61,
#         "sea_level": 1018,
#         "grnd_level": 929
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.33,
#         "deg": 67
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134619,
#     "sys": {
#         "country": "CA",
#         "sunrise": 1600091729,
#         "sunset": 1600137685
#     },
#     "timezone": -25200,
#     "id": 5911745,
#     "name": "Burns Lake",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 93.45,
#         "lat": 42.8
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 68.81,
#         "feels_like": 58.91,
#         "temp_min": 68.81,
#         "temp_max": 68.81,
#         "pressure": 1015,
#         "humidity": 21,
#         "sea_level": 1015,
#         "grnd_level": 932
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 10.09,
#         "deg": 110
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1600134621,
#     "sys": {
#         "country": "CN",
#         "sunrise": 1600125961,
#         "sunset": 1600171020
#     },
#     "timezone": 28800,
#     "id": 1529484,
#     "name": "Kumul",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -0.88,
#         "lat": 41.66
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 72.25,
#         "feels_like": 72.84,
#         "temp_min": 69.8,
#         "temp_max": 73.99,
#         "pressure": 1021,
#         "humidity": 77
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.05,
#         "deg": 80
#     },
#     "rain": {
#         "1h": 0.39
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1600134531,
#     "sys": {
#         "type": 1,
#         "id": 6439,
#         "country": "ES",
#         "sunrise": 1600148647,
#         "sunset": 1600193601
#     },
#     "timezone": 7200,
#     "id": 3104324,
#     "name": "Zaragoza",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 10.04,
#         "lat": 12.45
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 79.07,
#         "feels_like": 82.85,
#         "temp_min": 79.07,
#         "temp_max": 79.07,
#         "pressure": 1010,
#         "humidity": 66,
#         "sea_level": 1010,
#         "grnd_level": 969
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.03,
#         "deg": 172
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1600134623,
#     "sys": {
#         "country": "NG",
#         "sunrise": 1600146548,
#         "sunset": 1600190460
#     },
#     "timezone": 3600,
#     "id": 2339631,
#     "name": "Hadejia",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -52.26,
#         "lat": -15.89
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 75.06,
#         "feels_like": 72.23,
#         "temp_min": 75.06,
#         "temp_max": 75.06,
#         "pressure": 1015,
#         "humidity": 32,
#         "sea_level": 1015,
#         "grnd_level": 980
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.21,
#         "deg": 240
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1600134624,
#     "sys": {
#         "country": "BR",
#         "sunrise": 1600075484,
#         "sunset": 1600118664
#     },
#     "timezone": -14400,
#     "id": 3470709,
#     "name": "Barra do Gar\u00e7as",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -77.61,
#         "lat": -11.1
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 60.33,
#         "feels_like": 57.79,
#         "temp_min": 60.33,
#         "temp_max": 60.33,
#         "pressure": 1019,
#         "humidity": 84,
#         "sea_level": 1019,
#         "grnd_level": 1013
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 7.52,
#         "deg": 171
#     },
#     "clouds": {
#         "all": 28
#     },
#     "dt": 1600134625,
#     "sys": {
#         "country": "PE",
#         "sunrise": 1600081502,
#         "sunset": 1600124811
#     },
#     "timezone": -18000,
#     "id": 3939761,
#     "name": "Hualmay",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -97.95,
#         "lat": 23.17
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 77.72,
#         "feels_like": 82.44,
#         "temp_min": 77,
#         "temp_max": 78.01,
#         "pressure": 1017,
#         "humidity": 65
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.01,
#         "deg": 315,
#         "gust": 1.99
#     },
#     "clouds": {
#         "all": 86
#     },
#     "dt": 1600134626,
#     "sys": {
#         "type": 3,
#         "id": 2033166,
#         "country": "MX",
#         "sunrise": 1600085898,
#         "sunset": 1600130176
#     },
#     "timezone": -18000,
#     "id": 3522526,
#     "name": "Nuevo Progreso",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 97.52,
#         "lat": 50.6
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 44.4,
#         "feels_like": 41.2,
#         "temp_min": 44.4,
#         "temp_max": 44.4,
#         "pressure": 1020,
#         "humidity": 71,
#         "sea_level": 1020,
#         "grnd_level": 871
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 0.34,
#         "deg": 313
#     },
#     "clouds": {
#         "all": 77
#     },
#     "dt": 1600134627,
#     "sys": {
#         "country": "RU",
#         "sunrise": 1600124734,
#         "sunset": 1600170294
#     },
#     "timezone": 25200,
#     "id": 1501377,
#     "name": "Kungurtug",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 145.77,
#         "lat": -16.92
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 79.41,
#         "feels_like": 80.06,
#         "temp_min": 78.8,
#         "temp_max": 80.01,
#         "pressure": 1018,
#         "humidity": 74
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 12.75,
#         "deg": 150
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1600134479,
#     "sys": {
#         "type": 1,
#         "id": 9490,
#         "country": "AU",
#         "sunrise": 1600114348,
#         "sunset": 1600157526
#     },
#     "timezone": 36000,
#     "id": 2172797,
#     "name": "Cairns",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 121.02,
#         "lat": 14.35
#     },
#     "weather": [
#         {
#             "id": 501,
#             "main": "Rain",
#             "description": "moderate rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 78.39,
#         "feels_like": 86.36,
#         "temp_min": 78.01,
#         "temp_max": 78.8,
#         "pressure": 1008,
#         "humidity": 94
#     },
#     "visibility": 8000,
#     "wind": {
#         "speed": 5.82,
#         "deg": 20
#     },
#     "rain": {
#         "1h": 2.37
#     },
#     "clouds": {
#         "all": 90
#     },
#     "dt": 1600134629,
#     "sys": {
#         "type": 1,
#         "id": 8160,
#         "country": "PH",
#         "sunrise": 1600119886,
#         "sunset": 1600163865
#     },
#     "timezone": 28800,
#     "id": 1688781,
#     "name": "City of San Pedro",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 116.77,
#         "lat": 23.46
#     },
#     "weather": [
#         {
#             "id": 803,
#             "main": "Clouds",
#             "description": "broken clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 84.2,
#         "feels_like": 88.56,
#         "temp_min": 84.2,
#         "temp_max": 84.2,
#         "pressure": 1011,
#         "humidity": 70
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.95,
#         "deg": 100
#     },
#     "clouds": {
#         "all": 75
#     },
#     "dt": 1600134631,
#     "sys": {
#         "type": 1,
#         "id": 9632,
#         "country": "CN",
#         "sunrise": 1600120767,
#         "sunset": 1600165023
#     },
#     "timezone": 28800,
#     "id": 1795940,
#     "name": "Chenghai",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -88.73,
#         "lat": 42.83
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 61.36,
#         "feels_like": 60.49,
#         "temp_min": 60.01,
#         "temp_max": 62.01,
#         "pressure": 1026,
#         "humidity": 100
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.25,
#         "deg": 132
#     },
#     "clouds": {
#         "all": 9
#     },
#     "dt": 1600134632,
#     "sys": {
#         "type": 3,
#         "id": 2002976,
#         "country": "US",
#         "sunrise": 1600083252,
#         "sunset": 1600128397
#     },
#     "timezone": -18000,
#     "id": 5278931,
#     "name": "Whitewater",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -115.98,
#         "lat": 36.21
#     },
#     "weather": [
#         {
#             "id": 801,
#             "main": "Clouds",
#             "description": "few clouds",
#             "icon": "02d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 92.23,
#         "feels_like": 90.27,
#         "temp_min": 91,
#         "temp_max": 93.99,
#         "pressure": 1015,
#         "humidity": 19
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 1.01,
#         "deg": 151,
#         "gust": 1.01
#     },
#     "clouds": {
#         "all": 17
#     },
#     "dt": 1600134633,
#     "sys": {
#         "type": 3,
#         "id": 2018552,
#         "country": "US",
#         "sunrise": 1600089968,
#         "sunset": 1600134758
#     },
#     "timezone": -25200,
#     "id": 5509851,
#     "name": "Pahrump",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -73.92,
#         "lat": -14.8
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 36.93,
#         "feels_like": 32.25,
#         "temp_min": 36.93,
#         "temp_max": 36.93,
#         "pressure": 1021,
#         "humidity": 90,
#         "sea_level": 1021,
#         "grnd_level": 617
#     },
#     "visibility": 5657,
#     "wind": {
#         "speed": 2.59,
#         "deg": 283
#     },
#     "clouds": {
#         "all": 100
#     },
#     "dt": 1600134634,
#     "sys": {
#         "country": "PE",
#         "sunrise": 1600080665,
#         "sunset": 1600123877
#     },
#     "timezone": -18000,
#     "id": 3927995,
#     "name": "Tambo",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": -76.85,
#         "lat": 1.92
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 54.66,
#         "feels_like": 52.09,
#         "temp_min": 54.66,
#         "temp_max": 54.66,
#         "pressure": 1016,
#         "humidity": 85,
#         "sea_level": 1016,
#         "grnd_level": 783
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 4.83,
#         "deg": 115
#     },
#     "clouds": {
#         "all": 27
#     },
#     "dt": 1600134635,
#     "sys": {
#         "country": "CO",
#         "sunrise": 1600081149,
#         "sunset": 1600124799
#     },
#     "timezone": -18000,
#     "id": 3690136,
#     "name": "Almaguer",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 174.25,
#         "lat": -38.92
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 54,
#         "feels_like": 43.63,
#         "temp_min": 54,
#         "temp_max": 54,
#         "pressure": 1012,
#         "humidity": 76
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 17,
#         "deg": 284,
#         "gust": 30
#     },
#     "clouds": {
#         "all": 25
#     },
#     "dt": 1600134636,
#     "sys": {
#         "type": 3,
#         "id": 2020402,
#         "country": "NZ",
#         "sunrise": 1600107836,
#         "sunset": 1600150371
#     },
#     "timezone": 43200,
#     "id": 2208091,
#     "name": "Waitara",
#     "cod": 200
# }
# {
#     "coord": {
#         "lon": 145.78,
#         "lat": -7.96
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 80.94,
#         "feels_like": 85.14,
#         "temp_min": 80.94,
#         "temp_max": 80.94,
#         "pressure": 1011,
#         "humidity": 75,
#         "sea_level": 1011,
#         "grnd_level": 1009
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 8.21,
#         "deg": 216
#     },
#     "rain": {
#         "1h": 0.2528
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1600134637,
#     "sys": {
#         "country": "PG",
#         "sunrise": 1600114234,
#         "sunset": 1600157635
#     },
#     "timezone": 36000,
#     "id": 2094144,
#     "name": "Kerema",
#     "cod": 200
# }

# %%
weather_data = ({"City":city_list,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lng,
    "Max Temp":max_temp,
    "Wind Speed":wind_speed})

# %%
weather_df = pd.DataFrame(weather_data)

pd.DataFrame.to_csv(weather_df, 'weather_df.csv')
weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       ushuaia          40      AR  1600134035        93 -54.80  -68.30
# 1  puerto ayora          76      EC  1600134037        89  -0.74  -90.35
# 2   yellowknife          75      CA  1600134038        64  62.46 -114.35
# 3         kroya          93      ID  1600134039        67  -7.63  109.25
# 4  punta arenas          55      CL  1600133776        86 -53.15  -70.92
#
#    Max Temp  Wind Speed
# 0     35.60       17.22
# 1     66.99        5.01
# 2     46.40        8.05
# 3     80.69        6.31
# 4     37.40       25.28

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"])
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature in (F)")
plt.savefig("LatTemp.png")
plt.show()
print(f'As noted through this graph, we can see that through this sample there were more Northern cities. It almost creates a normal distribution curve as we see on both sides it starts at lower temperatures and as it gets to the middle of the equator, the temperature rises.')
# Out:
# As noted through this graph, we can see that through this sample there were more Northern cities. It almost creates a normal distribution curve as we see on both sides it starts at lower temperatures and as it gets to the middle of the equator, the temperature rises.

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"])
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("LatHum.png")
plt.show()
print(f'As noted through this graph, we can see that through this sample there is humidity throughout all areas. The latitude did not play a role in how humid the area is.')
# Out:
# As noted through this graph, we can see that through this sample there is humidity throughout all areas. The latitude did not play a role in how humid the area is.

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"])
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("LatCloud.png")
plt.show()
print(f'As noted through this graph, we can see that through this sample that there is not a correlation between the latitude and the cloudiness.')
# Out:
# As noted through this graph, we can see that through this sample that there is not a correlation between the latitude and the cloudiness.

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"])
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("LatWind.png")
plt.show()
print(f'As noted through this graph, we can see that through this sample that wind speeds are generally under 20 mph. There is not much correlation with the latitude')
# Out:
# As noted through this graph, we can see that through this sample that wind speeds are generally under 20 mph. There is not much correlation with the latitude

# %%
# Create Northern and Southern Hemisphere DataFrames
northern = weather_df.loc[weather_df["Lat"] >= 0]
southern = weather_df.loc[weather_df["Lat"] < 0]

# %%
x_values = northern["Lat"]
y_values = northern["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

#regression values
regression_values = x_values * slope + intercept

#Line equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

#plotting and formatting

plt.scatter(x_values, y_values)
plt.plot(x_values,regression_values,"r-")

plt.title(f'Northern Hemisphere Latitude vs Temp')
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("NorthLatTemp.png")
print(f'As noted through this graph, we can see that the Northern Hemisphere tends to fall in temperature the closer we get to the equator. The r-squared is under .7 which means the temperature is not closely correlated with the temperature. This sample does show more correlation to the lattiude than the sample with the Southern Hemisphere')
# Out:
# y = -0.63x + 89.85
# The r-squared is: 0.6655476044518375
# As noted through this graph, we can see that the Northern Hemisphere tends to fall in temperature the closer we get to the equator. The r-squared is under .7 which means the temperature is not closely correlated with the temperature. This sample does show more correlation to the lattiude than the sample with the Southern Hemisphere

# %%
x_values_2 = southern["Lat"]
y_values_2 = southern["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_2, y_values_2)

#regression values
regression_values_2 = x_values_2 * slope + intercept

#Line equation
line_eq_2 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq_2)

#plotting and formatting

plt.scatter(x_values_2, y_values_2)
plt.plot(x_values_2,regression_values_2,"r-")

plt.title(f'Southern Hemisphere Latitude vs Temp')
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("SouthLatTemp.png")
print(f'As noted through this graph, we can see that the Southern Hemisphere tends to rise in temperature the closer we get to the equator. The r-squared is under .7 which means the temperature is not closely correlated with the temperature')
# Out:
# y = 0.73x + 81.16
# The r-squared is: 0.545146689918203
# As noted through this graph, we can see that the Southern Hemisphere tends to rise in temperature the closer we get to the equator. The r-squared is under .7 which means the temperature is not closely correlated with the temperature

# %%
x_values = northern["Lat"]
humid_values = northern["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, humid_values)

#regression values
regression_values = x_values * slope + intercept

#Line equation
line_eq_3 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq_3)

#plotting and formatting

plt.scatter(x_values, humid_values)
plt.plot(x_values,regression_values,"r-")

plt.title(f'Northern Hemisphere Latitude vs Humidity')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("NorthLatHum.png")
print(f'As noted through this graph, we can see that the Northern Hemisphere does not have correlation between the latitude and humidity. In the month of this data, there was more humidity in the Norhern Hemisphere based on the samples')
# Out:
# y = 0.04x + 72.18
# The r-squared is: 0.0015718165879562089
# As noted through this graph, we can see that the Northern Hemisphere does not have correlation between the latitude and humidity. In the month of this data, there was more humidity in the Norhern Hemisphere based on the samples

# %%
x_values_2 = southern["Lat"]
humid_values_2 = southern["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_2, humid_values_2)

#regression values
regression_values = x_values_2 * slope + intercept

#Line equation
line_eq_4 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq_4)

#plotting and formatting

plt.scatter(x_values_2, humid_values_2)
plt.plot(x_values_2,regression_values,"r-")

plt.title(f'Southern Hemisphere Latitude vs Humidity')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("SouthLatHum.png")
print(f'As noted through this graph, we can see that the Southern Hemisphere does not have correlation between the latitude and humidity.')
# Out:
# y = 0.11x + 70.98
# The r-squared is: 0.006152149550493019
# As noted through this graph, we can see that the Southern Hemisphere does not have correlation between the latitude and humidity.

# %%
x_values = northern["Lat"]
cloud_values = northern["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, cloud_values)

#regression values
regression_values = x_values * slope + intercept

#Line equation
line_eq_5 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq_5)

#plotting and formatting

plt.scatter(x_values, cloud_values)
plt.plot(x_values,regression_values,"r-")

plt.title(f'Northern Hemisphere Latitude vs Cloudiness')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("NorthLatCloud.png")
print(f'As noted through this graph, we can see that the Northern Hemisphere does not have correlation between the latitude and cloudiness. In the month of this data, there seems to be an even spread of the sample with under 40% cloudiness and over 60% cloudiness.')
# Out:
# y = 0.12x + 48.04
# The r-squared is: 0.0038095866938567973
# As noted through this graph, we can see that the Northern Hemisphere does not have correlation between the latitude and cloudiness. In the month of this data, there seems to be an even spread of the sample with under 40% cloudiness and over 60% cloudiness.

# %%
x_values_2 = southern["Lat"]
cloud_values_2 = southern["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_2, cloud_values_2)

#regression values
regression_values = x_values_2 * slope + intercept

#Line equation
line_eq_6 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq_6)

#plotting and formatting

plt.scatter(x_values_2, cloud_values_2)
plt.plot(x_values_2,regression_values,"r-")

plt.title(f'Southern Hemisphere Latitude vs Cloudiness')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("SouthLatCloud.png")
print(f'As noted through this graph, we can see that the Southern Hemisphere does not have correlation between the latitude and cloudiness. In the month of this data, there seems to be an rising percent of cloudiness based on the regression line, however the correlation is very low. It is closer to zero which generally means no correlation.')
# Out:
# y = 0.16x + 44.22
# The r-squared is: 0.002831601993474904
# As noted through this graph, we can see that the Southern Hemisphere does not have correlation between the latitude and cloudiness. In the month of this data, there seems to be an rising percent of cloudiness based on the regression line, however the correlation is very low. It is closer to zero which generally means no correlation.

# %%
x_values = northern["Lat"]
wind_values = northern["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, wind_values)

#regression values
regression_values = x_values * slope + intercept

#Line equation
line_eq_7 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq_7)

#plotting and formatting

plt.scatter(x_values, wind_values)
plt.plot(x_values,regression_values,"r-")

plt.title(f'Northern Hemisphere Latitude vs Wind Speed')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("NorthLatWind.png")
print(f'As noted through this graph, we can see that the Northern Hemisphere does not have correlation between the latitude and wind speed. In the month of this data, there seems to be lower wind speeds through this data sample with a few outliers over 20 mph.')
# Out:
# y = 0.02x + 6.36
# The r-squared is: 0.008773417735863608
# As noted through this graph, we can see that the Northern Hemisphere does not have correlation between the latitude and wind speed. In the month of this data, there seems to be lower wind speeds through this data sample with a few outliers over 20 mph.

# %%
x_values_2 = southern["Lat"]
wind_values_2 = southern["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_2, wind_values_2)
#regression values
regression_values = x_values_2 * slope + intercept

#Line equation
line_eq_8 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq_8)

#plotting and formatting

plt.scatter(x_values_2, wind_values_2)
plt.plot(x_values_2,regression_values,"r-")

plt.title(f'Southern Hemisphere Latitude vs Wind Speed')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")
print(f"The r-squared is: {rvalue**2}")
plt.show()
plt.savefig("SouthLatWind.png")
print(f'As noted through this graph, we can see that the Southern Hemisphere does not have correlation between the latitude and wind speed.')
# Out:
# y = -0.12x + 6.07
# The r-squared is: 0.07735202517048465
# As noted through this graph, we can see that the Southern Hemisphere does not have correlation between the latitude and wind speed.
